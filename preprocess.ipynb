# %%
import pandas as pd
import requests
import datetime
from dateutil import parser
from tqdm.auto import tqdm
import json
import re

# -----------------------------------
# 1. Read the CSV data
# -----------------------------------
df_bills = pd.read_csv("crec2023.csv")

# Remove rows where speaker starts with any of The CLERK, The SPEAKER, The PRESIDENT, The PRESIDING OFFICER, The Acting CHAIR, The CHAIR, The ACTING PRESIDENT case-insensitive
df_bills = df_bills[~df_bills["speaker"].str.lower().str.startswith(("the clerk", "the speaker", "the president", "the presiding officer", "the acting chair", "the chair", "the acting president"), na=False)]

# Filter out rows where speech is less than 250 characters, to filter out procedural speehces
df_bills = df_bills[df_bills['speech'].str.len() >= 250]
# -----------------------------------
# 2. Identify potential bills
#    Simple criterion: title contains the word 'ACT'
# -----------------------------------

# Drop or fill missing values in the 'title' column
df_bills = df_bills.dropna(subset=["title"])

# Filter rows where 'title' contains ' ACT'
df_bills = df_bills[df_bills["title"].str.contains(" ACT", na=False, case=False)]  # Ignore case if needed

def preprocess_text(text):
    # Replace all consecutive whitespaces with a single whitespace
    text = re.sub(r'\s+', ' ', text)
    # Replace Madam Speaker, Mr. President, Madam President with Mr. Speaker
    text = re.sub(r'Mr\. President', 'Mr. Speaker', text)
    text = re.sub(r'Mr\. Clerk', 'Mr. Speaker', text)
    text = re.sub(r'Mr\. Chair', 'Mr. Speaker', text)
    text = re.sub(r'Mr\. Chairman', 'Mr. Speaker', text)
    text = re.sub(r'Mr\. Speakerman', 'Mr. Speaker', text)
    text = re.sub(r'Madam President', 'Mr. Speaker', text)
    text = re.sub(r'Madam Speaker', 'Mr. Speaker', text)
    text = re.sub(r'Madam Clerk', 'Mr. Speaker', text)
    text = re.sub(r'Madam Chair', 'Mr. Speaker', text)
    text = re.sub(r'Madam Chairman', 'Mr. Speaker', text)
    text = re.sub(r'Madam Chairwoman', 'Mr. Speaker', text)

    # "Mr. Speaker, " 
    text = re.sub(r'^Mr\. Speaker, ', '', text)
    # Strike starting sentence that starts with "I yield"
    text = re.sub(r'^I yield.*?\. *', '', text)
    # Remove second "Mr. Speaker, " that sometimes follows
    text = re.sub(r'^Mr\. Speaker, ', '', text)

    return text

df_bills['speech'] = df_bills.apply(lambda x: preprocess_text(x['speech']), axis=1)


# # Write df_bills to csv
df_bills.to_csv("df_bills.csv", index=False)

df_bills.head()
# Out:
#                         speech_id  \
# 58   CREC-2023-01-09-pt1-PgE3-4-2
# 198  CREC-2023-01-09-pt1-PgH76-12
# 199  CREC-2023-01-09-pt1-PgH76-13
# 200  CREC-2023-01-09-pt1-PgH76-15
# 201  CREC-2023-01-09-pt1-PgH76-16
#
#                                                 speech chamber  is_extension  \
# 58   I rise today to introduce the District of Colu...       H          True
# 198  the process for considering our first bill of ...       H         False
# 199  I rise in strong opposition to H.R. 23. My fri...       H         False
# 200  he points out in the opening paragraph of a ta...       H         False
# 201  I include in the Record an excerpt from a 2021...       H         False
#
#          date                speaker speaker_bioguide  vol  num  congress_num  \
# 58   1/9/2023             Ms. NORTON          N000147  169    7           118
# 198  1/9/2023  Mr. SMITH of Nebraska          S001172  169    7           118
# 199  1/9/2023               Mr. NEAL          N000015  169    7           118
# 200  1/9/2023               Mr. NEAL          N000015  169    7           118
# 201  1/9/2023  Mr. SMITH of Nebraska          S001172  169    7           118
#
#        pages                                          doc_title  \
# 58     E3-E4  INTRODUCTION OF THE WASHINGTON, D.C. ADMISSION...
# 198  H76-H94  FAMILY AND SMALL BUSINESS TAXPAYER PROTECTION ACT
# 199  H76-H94  FAMILY AND SMALL BUSINESS TAXPAYER PROTECTION ACT
# 200  H76-H94  FAMILY AND SMALL BUSINESS TAXPAYER PROTECTION ACT
# 201  H76-H94  FAMILY AND SMALL BUSINESS TAXPAYER PROTECTION ACT
#
#                                                  title
# 58   INTRODUCTION OF THE WASHINGTON, D.C. ADMISSION...
# 198  FAMILY AND SMALL BUSINESS TAXPAYER PROTECTION ACT
# 199  FAMILY AND SMALL BUSINESS TAXPAYER PROTECTION ACT
# 200  FAMILY AND SMALL BUSINESS TAXPAYER PROTECTION ACT
# 201  FAMILY AND SMALL BUSINESS TAXPAYER PROTECTION ACT

# %%
API_KEY = "api_key"
BASE_URL = "https://api.congress.gov/v3"
CONGRESS_NUMBER = 118

# %%
url = f"{BASE_URL}/bill/{CONGRESS_NUMBER}/{'hr'}/{3691}/subjects"
params = {"api_key": API_KEY, "format": "json"}
resp = requests.get(url, params=params)
data = resp.json()
data
# Out:
# {'pagination': {'count': 7},
#  'request': {'billNumber': '3691',
#   'billType': 'hr',
#   'billUrl': 'https://api.congress.gov/v3/bill/118/hr/3691?format=json',
#   'congress': '118',
#   'contentType': 'application/json',
#   'format': 'json'},
#  'subjects': {'legislativeSubjects': [{'name': 'Aviation and airports',
#     'updateDate': '2024-01-08T20:30:29Z'},
#    {'name': 'Congressional oversight', 'updateDate': '2024-01-08T20:30:29Z'},
#    {'name': 'Emergency medical services and trauma care',
#     'updateDate': '2024-01-08T20:30:29Z'},
#    {'name': 'Government studies and investigations',
#     'updateDate': '2024-01-08T20:30:29Z'},
#    {'name': 'Health care costs and insurance',
#     'updateDate': '2024-01-08T20:30:29Z'},
#    {'name': 'Medicare', 'updateDate': '2024-01-08T20:30:29Z'}],
#   'policyArea': {'name': 'Health', 'updateDate': '2023-06-21T15:46:05Z'}}}

# %%
data.get("subjects").get("policyArea").get("name")
# Out:
# 'Health'

# %%
def get_bill_subjects_and_policy_area(api_key, congress, bill_type, bill_number):
    """
    Returns:
        {
           "policy_area": {
               "name": str,
               "updateDate": str or None
           },
           "legislative_subjects": [
               {
                 "name": str,
                 "updateDate": str or None
               },
               ...
           ]
        }
    or an empty dict if no data is found or request fails.
    """
    url = f"{BASE_URL}/bill/{congress}/{bill_type.lower()}/{bill_number}/subjects"
    params = {"api_key": api_key, "format": "json"}
    resp = requests.get(url, params=params)
    if resp.status_code != 200:
        return {}
    data = resp.json()
    
    subjects_data = data.get("subjects", {})
    
    # Policy area
    policy_area = subjects_data.get("policyArea", {})
    
    # Legislative subjects (list)
    legislative_subjects = subjects_data.get("legislativeSubjects", [])
    
    return {
        "policy_area": {
            "name": policy_area.get("name", ""),
            "updateDate": policy_area.get("updateDate")
        },
        "legislative_subjects": [
            {
                "name": s.get("name", ""),
                "updateDate": s.get("updateDate")
            }
            for s in legislative_subjects
        ]
    }

def get_bill_summaries_all(api_key, congress, bill_type, bill_number):
    """
    Returns a list of all summaries, each item:
        {
          "actionDate": str (YYYY-MM-DD),
          "actionDesc": str,
          "text": str,
          "updateDate": str,
          "versionCode": str
        }
    """
    url = f"{BASE_URL}/bill/{congress}/{bill_type.lower()}/{bill_number}/summaries"
    params = {"api_key": api_key, "format": "json"}
    resp = requests.get(url, params=params)
    if resp.status_code != 200:
        return []
    data = resp.json()
    return data.get("summaries", [])

def get_bill_committees_all(api_key, congress, bill_type, bill_number):
    """
    Returns a list of committees. Each committee looks like:
        {
            "name": str,
            "chamber": str,
            "type": str,
            "activities": [
               {"date": "2023-05-29T18:00:30Z", "name": "Referred To"}, ...
            ],
            "subcommittees": [
               {
                  "name": "...",
                  "activities": [...],
                  ...
               },
               ...
            ]
        }
    """
    url = f"{BASE_URL}/bill/{congress}/{bill_type.lower()}/{bill_number}/committees"
    params = {"api_key": api_key, "format": "json"}
    resp = requests.get(url, params=params)
    if resp.status_code != 200:
        return []
    data = resp.json()
    return data.get("committees", [])

# %%
def fetch_and_cache_bill_data(api_key, congress, bill_type, bill_number):
    """
    Fetches all the relevant data for a single bill
    (subjects, policy area, all summaries, committees, etc.)
    Returns a dict with keys:
        "bill_type", "bill_number", "subjects_policy", "summaries", "committees"
    """
    result = {}
    # subjects & policy area
    result["subjects_policy"] = get_bill_subjects_and_policy_area(api_key, congress, bill_type, bill_number)
    # summaries
    result["summaries"] = get_bill_summaries_all(api_key, congress, bill_type, bill_number)
    # committees
    result["committees"] = get_bill_committees_all(api_key, congress, bill_type, bill_number)
    return result

# %%
all_bills_dict = {}

# %%
def build_bill_data_dict(api_key, all_bills, congress=118, limit_per_page=250, offset=0):
    """
    Returns a dictionary: 
      { 
          <lowercase bill title> : {
               "title": str,
               "bill_type": str,
               "bill_number": str,
               "url": str,
               "updateDate": str,
               # plus the deeper fetched data:
               "subjects_policy": {...},
               "summaries": [...],
               "committees": [...]
          },
          ...
      }
    """
    report = 1000
    while True:
        params = {
            "api_key": api_key,
            "format": "json",
            "offset": offset,
            "limit": limit_per_page
        }
        url = f"{BASE_URL}/bill/{congress}"
        resp = requests.get(url, params=params)
        resp.raise_for_status()
        data = resp.json()
        
        bills_page = data.get("bills", [])
        if not bills_page:
            break
        
        # For each bill in this page, store minimal metadata
        for b in bills_page:
            offset += 1
            b_title_lower = b.get("title", "").lower()
            if b_title_lower not in all_bills:
                all_bills[b_title_lower] = {
                    "title": b.get("title", "").strip("."),
                    "bill_type": b.get("type", ""),
                    "bill_number": b.get("number", ""),
                    "url": b.get("url", ""),
                    "updateDate": b.get("updateDate", "")
                }

        if offset >= report:
            print(offset)
            report += 1000


build_bill_data_dict(API_KEY, all_bills_dict, CONGRESS_NUMBER, offset=0)

with open("all_bills_dict.json", "w") as f:
    json.dump(all_bills_dict, f, indent=2)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000

# %%
with open("all_bills_dict.json", "r") as f:
    all_bills_dict = json.load(f)

# %%
# Now for each stored bill, fetch deeper data (subjects, committees, etc.)
for title_lower, info in tqdm(all_bills_dict.items()):
    # if we already have the deeper data, skip
    bt = info["bill_type"]
    bn = info["bill_number"]
    # fetch the deeper data
    fetched = fetch_and_cache_bill_data(API_KEY, CONGRESS_NUMBER, bt, bn)
    info.update(fetched)

with open("all_bills_dict.json", "w") as f:
    json.dump(all_bills_dict, f, indent=2)
# Out:
#   0%|          | 15/16020 [00:23<7:05:28,  1.60s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 9
#       7     bn = info["bill_number"]
#       8     # fetch the deeper data
# ----> 9     fetched = fetch_and_cache_bill_data(API_KEY, CONGRESS_NUMBER, bt, bn)
#      10     info.update(fetched)
#      12 with open("all_bills_dict.json", "w") as f:
#
# Cell In[4], line 14, in fetch_and_cache_bill_data(api_key, congress, bill_type, bill_number)
#      12 result["summaries"] = get_bill_summaries_all(api_key, congress, bill_type, bill_number)
#      13 # committees
# ---> 14 result["committees"] = get_bill_committees_all(api_key, congress, bill_type, bill_number)
#      15 return result
#
# Cell In[3], line 89, in get_bill_committees_all(api_key, congress, bill_type, bill_number)
#      87 url = f"{BASE_URL}/bill/{congress}/{bill_type.lower()}/{bill_number}/committees"
#      88 params = {"api_key": api_key, "format": "json"}
# ---> 89 resp = requests.get(url, params=params)
#      90 if resp.status_code != 200:
#      91     return []
#
# File ~/.conda/envs/thesis/lib/python3.9/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/.conda/envs/thesis/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.conda/envs/thesis/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.conda/envs/thesis/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.conda/envs/thesis/lib/python3.9/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/.conda/envs/thesis/lib/python3.9/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/.conda/envs/thesis/lib/python3.9/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/.conda/envs/thesis/lib/python3.9/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File ~/.conda/envs/thesis/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File ~/.conda/envs/thesis/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File ~/.conda/envs/thesis/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File ~/.conda/envs/thesis/lib/python3.9/socket.py:716, in SocketIO.readinto(self, b)
#     714 while True:
#     715     try:
# --> 716         return self._sock.recv_into(b)
#     717     except timeout:
#     718         self._timeout_occurred = True
#
# File ~/.conda/envs/thesis/lib/python3.9/ssl.py:1275, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1271     if flags != 0:
#    1272         raise ValueError(
#    1273           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1274           self.__class__)
# -> 1275     return self.read(nbytes, buffer)
#    1276 else:
#    1277     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.conda/envs/thesis/lib/python3.9/ssl.py:1133, in SSLSocket.read(self, len, buffer)
#    1131 try:
#    1132     if buffer is not None:
# -> 1133         return self._sslobj.read(len, buffer)
#    1134     else:
#    1135         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
with open("all_bills_dict.json", "r") as f:
    all_bills_dict = json.load(f)

# %%
def standardize_bill_title(title):
    """
    Standardize a bill title by:
    1. Converting to lowercase
    2. Combining multiple spaces into single space
    3. Removing specific prefixes and suffixes
    4. Removing specific procedural phrases
    
    Args:
        title (str): Original bill title
        
    Returns:
        str: Standardized bill title, or None if input is None/empty
    """
    if not title:
        return None
        
    # Convert to lowercase
    title = title.lower()
    
    # Combine multiple spaces into one
    title = ' '.join(title.split())
    
    # Skip titles that begin with "authorizing the clerk"
    if title.startswith("authorizing the clerk"):
        return None
        
    # Remove various prefixes up to the next comma
    prefixes_with_comma = [
        "providing for consideration of",
        "providing for further consideration of",
        "report on"
    ]
    
    for prefix in prefixes_with_comma:
        if title.startswith(prefix):
            comma_pos = title.find(", ")
            if comma_pos != -1:
                title = title[comma_pos + 2:]  # +2 to skip the comma and space
                break
    
    # Remove simple prefixes
    simple_prefixes = [
        "introduction of the ",
        "reintroduction of the "
    ]
    
    for prefix in simple_prefixes:
        if title.startswith(prefix):
            title = title[len(prefix):]
            
    # Remove trailing period or "--"
    if title.endswith("."):
        title = title[:-1]
    if title.endswith("--"):
        title = title[:-2]
        
    # Trim any resulting whitespace
    title = title.strip()
    
    return title if title else None

def get_bill_data(title, all_bills_dict):
    """
    Get the bill data (policy area, legislative subjects, summary, committees).
    Date checks removed - will return most recent data regardless of speech date.
    
    Args:
        title (str): Title of the bill
        all_bills_dict (dict): Dictionary containing bill data
        
    Returns:
        dict: Dictionary containing relevant bill data, or None if not found
    """
    # Standardize the title
    title_std = standardize_bill_title(title)
    if not title_std:
        return None
    
    # Try to find the bill in the dictionary
    if title_std not in all_bills_dict:
        return None
    
    bill_data = all_bills_dict[title_std]
    
    result = {
        'bill_type': bill_data.get('bill_type') or None,
        'bill_number': bill_data.get('bill_number') or None,
        'policy_area': None,
        'policy_area_update': None,
        'legislative_subjects': [],
        'latest_summary': None,
        'latest_summary_date': None,
        'committees': []
    }
    
    # Get policy area
    policy_area_data = bill_data.get('subjects_policy', {}).get('policy_area', {})
    if policy_area_data:
        result['policy_area'] = policy_area_data.get('name') or None
        if policy_area_data.get('updateDate'):
            result['policy_area_update'] = parser.parse(policy_area_data['updateDate']).date().isoformat()
    
    # Get legislative subjects
    leg_subjects = bill_data.get('subjects_policy', {}).get('legislative_subjects', [])
    for subject in leg_subjects:
        subject_data = {
            'name': subject.get('name') or None,
            'updateDate': parser.parse(subject['updateDate']).date().isoformat() if subject.get('updateDate') else None
        }
        result['legislative_subjects'].append(subject_data)
    
    # Get most recent summary
    summaries = bill_data.get('summaries', [])
    if summaries:
        # Get the most recent summary
        latest_summary = max(summaries, key=lambda x: parser.parse(x['actionDate']).date() if x.get('actionDate') else parser.parse('1900-01-01').date())
        result['latest_summary'] = latest_summary.get('text')
        if latest_summary.get('actionDate'):
            result['latest_summary_date'] = parser.parse(latest_summary['actionDate']).date().isoformat()
    
    # Get committees with their subcommittees
    committees = bill_data.get('committees', [])
    
    for committee in committees:
        committee_data = {
            'name': committee.get('name') or None,
            'chamber': committee.get('chamber') or None,
            'type': committee.get('type') or None,
            'latest_activity': None,
            'subcommittees': []
        }
        
        # Get latest committee activity
        activities = committee.get('activities', [])
        if activities:
            latest_activity = max(activities, key=lambda x: parser.parse(x['date']).date() if x.get('date') else parser.parse('1900-01-01').date())
            if latest_activity.get('date'):
                committee_data['latest_activity'] = parser.parse(latest_activity['date']).date().isoformat()
        
        # Get subcommittees
        for subcommittee in committee.get('subcommittees', []):
            sub_activities = subcommittee.get('activities', [])
            if sub_activities:
                latest_sub_activity = max(sub_activities, key=lambda x: parser.parse(x['date']).date() if x.get('date') else parser.parse('1900-01-01').date())
                if latest_sub_activity.get('date'):
                    subcommittee_data = {
                        'name': subcommittee.get('name') or None,
                        'latest_activity': parser.parse(latest_sub_activity['date']).date().isoformat()
                    }
                    committee_data['subcommittees'].append(subcommittee_data)
        
        result['committees'].append(committee_data)
    
    return result


# Before processing df_bills, standardize all titles in all_bills_dict
print("Standardizing bill titles in dictionary...")
standardized_bills_dict = {}
for title, data in all_bills_dict.items():
    std_title = standardize_bill_title(title)
    if std_title:
        standardized_bills_dict[std_title] = data
all_bills_dict = standardized_bills_dict

# Apply the function to each row in df_bills
print("Adding bill data columns...")
bill_data_list = []
for _, row in tqdm(df_bills.iterrows(), total=len(df_bills)):
    bill_data = get_bill_data(row['title'], all_bills_dict)
    bill_data_list.append(bill_data if bill_data else {})

# Add new columns to df_bills
df_bills['standardized_title'] = df_bills['title'].apply(standardize_bill_title)
df_bills['bill_type'] = [data.get('bill_type') for data in bill_data_list]
df_bills['bill_number'] = [data.get('bill_number') for data in bill_data_list]
df_bills['policy_area'] = [data.get('policy_area') for data in bill_data_list]
df_bills['legislative_subjects'] = [data.get('legislative_subjects', []) for data in bill_data_list]
df_bills['latest_summary'] = [data.get('latest_summary') for data in bill_data_list]
df_bills['committees'] = [data.get('committees', []) for data in bill_data_list]

print("Done!")
# Out:
# Standardizing bill titles in dictionary...
# Adding bill data columns...
# 100%|██████████| 5555/5555 [00:03<00:00, 1409.84it/s]
# Done!

# %%
# write df_bills to csv
df_bills.to_csv("df_bills.csv", index=False)

# %%
# list speakers from df_bills, sorted alphabetically
sorted(df_bills['title'].unique())
# Out:
# ['ACCREDITED INVESTOR DEFINITION REVIEW ACT',
#  'ACCURATELY COUNTING RISK ELIMINATION SOLUTIONS ACT',
#  'ADVANCED, LOCAL EMERGENCY RESPONSE TELECOMMUNICATIONS PARITY ACT',
#  'AFFIRMATIVE ACTION',
#  'AFFIRMATIVE ACTION DECISION',
#  'AFFORDABLE CARE ACT',
#  'AGRICULTURE, RURAL DEVELOPMENT, FOOD AND DRUG ADMINISTRATION, AND  RELATED AGENCIES APPROPRIATIONS ACT, 2024',
#  'AIRPORT AND AIRWAY EXTENSION ACT OF 2023, PART II',
#  'ALL-AMERICAN FLAG ACT',
#  'AMENDING THE FEDERAL ELECTION CAMPAIGN ACT OF 1971 TO EXTEND THE  ADMINISTRATIVE FINE PROGRAM FOR CERTAIN REPORTING VIOLATIONS',
#  'AMENDING THE INVESTMENT ADVISERS ACT OF 1940 TO CODIFY CERTAIN  SECURITIES AND EXCHANGE COMMISSION NO-ACTION LETTERS THAT EXCLUDE',
#  'AMERICAN BATTLEFIELD PROTECTION PROGRAM ENHANCEMENT ACT OF 2023',
#  'AMERICANS ARE DEMANDING ACTION',
#  "APPLICABILITY OF THE AIRLINE DEREGULATION ACT TO STATE WORKERS'  COMPENSATION PROGRAMS",
#  'ARMENIAN PROTECTION ACT OF 2023',
#  'AUTHORIZING THE CLERK TO MAKE CORRECTIONS IN ENGROSSMENT OF H.R. 1,  LOWER ENERGY COSTS ACT',
#  'AUTHORIZING THE CLERK TO MAKE CORRECTIONS IN ENGROSSMENT OF H.R. 21,  STRATEGIC PRODUCTION RESPONSE ACT',
#  'AUTHORIZING THE CLERK TO MAKE TECHNICAL CORRECTIONS IN ENGROSSMENT OF  H.R. 4365, DEPARTMENT OF DEFENSE APPROPRIATIONS ACT, 2024; H.R. 4367,  DEPARTMENT OF HOMELAND SECURITY APPROPRIATIONS ACT, 2024; AND H.R.',
#  'AUTHORIZING THE CLERK TO MAKE TECHNICAL CORRECTIONS IN ENGROSSMENT OF  H.R. 5933, DEFENDING EDUCATION TRANSPARENCY AND ENDING ROGUE REGIMES  ENGAGING IN NEFARIOUS TRANSACTIONS ACT',
#  'BIDEN FAMILY ALLEGED CRIMINAL ACTIVITIES',
#  'BIPARTISAN ACTION ON GUN VIOLENCE',
#  'BLOCK GRANT ASSISTANCE ACT OF 2023',
#  'BORN-ALIVE ABORTION SURVIVORS PROTECTION ACT',
#  'BUILDING CHIPS IN AMERICA ACT OF 2023',
#  'CELEBRATING 40 YEARS OF THE ROSELLE ACTIVE SENIORS GROUP',
#  'CELEBRATING THE OUTSTANDING LIFE OF ACTIVIST AND COUSHATTA LEADER  ERNEST SICKEY',
#  'CHANCE TO COMPETE ACT OF 2023',
#  'CHANGING AGE-DETERMINED ELIGIBILITY TO STUDENT INCENTIVE PAYMENTS ACT',
#  'CHINA FINANCIAL THREAT MITIGATION ACT OF 2023',
#  'CHIPS AND SCIENCE ACT',
#  'CHOICE ARRANGEMENT ACT',
#  'CHOICE IN AUTOMOBILE RETAIL SALES ACT OF 2023',
#  'CLOSE AGENCY LOOPHOLES TO THE JONES ACT',
#  'CLOSING ACT 22 AND FEDERAL TAX LOOPHOLES',
#  'COASTAL COMMUNITIES OCEAN ACIDIFICATION ACT OF 2023',
#  'COMBATING HUMAN RIGHTS ABUSES ACT OF 2023',
#  'COMMEMORATING 60TH ANNIVERSARY OF EQUAL PAY ACT',
#  'COMMEMORATING THE ANNIVERSARY OF THE AMERICANS WITH DISABILITIES ACT',
#  'COMMEMORATING THE VOTING RIGHTS ACT OF 1965',
#  'COMMERCIAL REMOTE SENSING AMENDMENT ACT OF 2023',
#  'COMMITMENT TO VETERAN SUPPORT AND OUTREACH ACT',
#  'COMPREHENSIVE POLICING AND JUSTICE AMENDMENT ACT',
#  'CONCERNS ABOUT H.R. 5378, THE LOWER COSTS, MORE TRANSPARENCY ACT',
#  'CONDEMN ALL ACTS OF POLITICAL VIOLENCE',
#  'CONDEMNING ALL ACTS OF VIOLENCE',
#  'CONDEMNING INTIMIDATION TACTICS OF PRO-ABORTION ACTIVISTS',
#  'CONDEMNING RECENT ACTIONS TAKEN BY THE RUSSIAN MILITARY TO DOWN A  UNITED STATES AIR FORCE DRONE',
#  'CONDEMNING THE ACTIONS OF NEW MEXICO GOVERNOR MICHELLE LUJAN GRISHAM',
#  'CONGRESS NEEDS TO ACT ON IMMIGRATION REFORM',
#  'CONGRESSIONAL AWARD PROGRAM REAUTHORIZATION ACT OF 2023',
#  'CONTINUING APPROPRIATIONS ACT, 2024 AND OTHER EXTENSIONS ACT',
#  'CONTINUING APPROPRIATIONS AND BORDER SECURITY ENHANCEMENT ACT, 2024',
#  'COSPONSORSHIP OF H.R.830--HELP COPAYS ACT',
#  'COST ESTIMATE FOR H.R. 3091, THE FEDERAL LAW ENFORCEMENT OFFICER  SERVICE WEAPON PURCHASE ACT',
#  'COST-SHARE ACCOUNTABILITY ACT OF 2023',
#  'COUNTERING UNTRUSTED TELECOMMUNICATIONS ABROAD ACT',
#  'COUNTERING WEAPONS OF MASS DESTRUCTION EXTENSION ACT OF 2023',
#  'COVID-19 ORIGIN ACT OF 2023',
#  'CREDIT CARD COMPETITION ACT OF 2023',
#  'CREDIT UNION BOARD MODERNIZATION ACT',
#  'CUSTOM HEALTH OPTION AND INDIVIDUAL CARE EXPENSE ARRANGEMENT ACT',
#  'DEADLINE FOR BACKDATED HONORING OUR PACT ACT BENEFITS',
#  'DEBBIE SMITH ACT OF 2023',
#  'DEFENDING EDUCATION TRANSPARENCY AND ENDING ROGUE REGIMES ENGAGING IN  NEFARIOUS TRANSACTIONS ACT',
#  'DEFENSE PRODUCTION ACT AND MEDICINE',
#  'DEFUND ACT',
#  'DEPARTMENT OF DEFENSE APPROPRIATIONS ACT, 2024',
#  'DEPARTMENT OF HOMELAND SECURITY APPROPRIATIONS ACT, 2024',
#  'DEPARTMENT OF STATE, FOREIGN OPERATIONS, AND RELATED PROGRAMS  APPROPRIATIONS ACT, 2024',
#  'DEPARTMENT OF THE INTERIOR, ENVIRONMENT, AND RELATED AGENCIES  APPROPRIATIONS ACT, 2024',
#  'DEPARTMENT OF VETERANS AFFAIRS CREATION OF ON-SITE TREATMENT SYSTEMS  AFFORDING VETERANS IMPROVEMENTS AND NUMEROUS GENERAL SAFETY  ENHANCEMENTS ACT',
#  'DEPARTMENTS OF LABOR, HEALTH AND HUMAN SERVICES, AND EDUCATION, AND  RELATED AGENCIES APPROPRIATIONS ACT, 2024',
#  'DISAPPROVING THE ACTION OF THE DISTRICT OF COLUMBIA COUNCIL IN  APPROVING THE COMPREHENSIVE POLICING AND JUSTICE REFORM AMENDMENT ACT',
#  'DISAPPROVING THE ACTION OF THE DISTRICT OF COLUMBIA COUNCIL IN  APPROVING THE COMPREHENSIVE POLICING AND JUSTICE REFORM AMENDMENT ACT  OF 2022',
#  'DISAPPROVING THE ACTION OF THE DISTRICT OF COLUMBIA COUNCIL IN  APPROVING THE LOCAL RESIDENT VOTING RIGHTS AMENDMENT ACT OF 2022',
#  'DISAPPROVING THE ACTION OF THE DISTRICT OF COLUMBIA COUNCIL IN  APPROVING THE REVISED CRIMINAL CODE ACT OF 2022',
#  'DISASTER ASSISTANCE SIMPLIFICATION ACT',
#  'DOE AND NSF INTERAGENCY RESEARCH ACT',
#  'DOE AND USDA INTERAGENCY RESEARCH ACT',
#  "DR. EMMANUEL BILIRAKIS AND HONORABLE JENNIFER WEXTON NATIONAL PLAN TO  END PARKINSON'S ACT",
#  'DUCK STAMP MODERNIZATION ACT OF 2023',
#  'EASTERN BAND OF CHEROKEE HISTORIC LANDS REACQUISITION ACT',
#  'ELIMINATE USELESS REPORTS ACT OF 2023',
#  'ELIZABETH DOLE HOME- AND COMMUNITY-BASED SERVICES FOR VETERANS AND  CAREGIVERS ACT OF 2023',
#  'EMERGENCY WILDFIRE FIGHTING TECHNOLOGY ACT OF 2023',
#  'EMPLOYER REPORTING IMPROVEMENT ACT',
#  'ENCOURAGING PUBLIC OFFERINGS ACT OF 2023',
#  'ENDING AFFIRMATIVE ACTION IS MEAN-SPIRITED',
#  'ENERGY AND WATER DEVELOPMENT AND RELATED AGENCIES APPROPRIATIONS ACT,',
#  'ENHANCING MULTI-CLASS SHARE DISCLOSURES ACT',
#  'ENSURING ACCOUNTABILITY IN AGENCY RULEMAKING ACT',
#  'EQUAL OPPORTUNITY FOR ALL INVESTORS ACT OF 2023',
#  'EXPANDING ACCESS TO CAPITAL FOR RURAL JOB CREATORS ACT',
#  'FAIR INVESTMENT OPPORTUNITIES FOR PROFESSIONAL EXPERTS ACT',
#  'FAIR SHIPPING FOR NON-CONTIGUOUS AREAS ACT OF 2023',
#  'FAMILY AND SMALL BUSINESS TAXPAYER PROTECTION ACT',
#  'FEDERAL DISASTER ASSISTANCE COORDINATION ACT',
#  'FEDERAL LAW ENFORCEMENT OFFICER SERVICE WEAPON PURCHASE ACT',
#  'FEND OFF FENTANYL ACT',
#  'FIGHT AND COMBAT RAMPANT IRANIAN MISSILE EXPORTS ACT',
#  'FINANCIAL EXPLOITATION PREVENTION ACT OF 2023',
#  'FINANCIAL SERVICES AND GENERAL GOVERNMENT APPROPRIATIONS ACT, 2024',
#  'FIRE GRANTS AND SAFETY ACT',
#  'FIRST RESPONDER ACCESS TO INNOVATIVE TECHNOLOGIES ACT',
#  'FISCAL RESPONSIBILITY ACT OF 2023',
#  'FISCAL RESPONSIBILITY ACT OF 2023--MOTION TO PROCEED',
#  'FOREIGN AFFILIATES SHARING PILOT PROGRAM EXTENSION ACT',
#  'FORT SAN GERONIMO PRESERVATION ACT',
#  'FREEDOM FOR HEALTH CARE WORKERS ACT',
#  'FURTHER CONTINUING APPROPRIATIONS AND OTHER EXTENSIONS ACT, 2024',
#  'GAO INSPECTOR GENERAL PARITY ACT',
#  'GAS STOVE PROTECTION AND FREEDOM ACT',
#  'GLOBAL INVESTMENT IN AMERICAN JOBS ACT OF 2023',
#  'GO WOKE, GO BROKE ACT',
#  'GRAND RONDE RESERVATION ACT AMENDMENT OF 2023',
#  'H.R. 2, THE SECURE THE BORDER ACT OF 2023',
#  'HAITI CRIMINAL COLLUSION TRANSPARENCY ACT OF 2023',
#  'HALT ALL LETHAL TRAFFICKING OF FENTANYL ACT',
#  'HAMAS AND OTHER PALESTINIAN TERRORIST GROUPS INTERNATIONAL FINANCING  PREVENTION ACT',
#  "HERSHEL ``WOODY'' WILLIAMS NATIONAL MEDAL OF HONOR MONUMENT LOCATION  ACT",
#  'HOLD BAD ACTORS ACCOUNTABLE FOR ILLEGAL TRADING PRACTICES',
#  "HONORING GEORGETOWN UNIVERSITY'S CORRECTIVE ACTION TO THE INSTITUTION  OF SLAVERY",
#  'HONORING GLADYS KNIGHT, SINGER, SONGWRITER, ACTRESS, AND BUSINESSWOMAN',
#  'HONORING MRS. ANGIE WOMBLE RAWLS ON THE OCCASION OF HER RETIREMENT AS  DIRECTOR OF CHORAL ACTIVITIES AT PEARL HIGH SCHOOL',
#  'HONORING OUR COURAGEOUS SERVICEMEMBERS WITH THE FLAG ACT',
#  'HONORING THE HEROIC ACTIONS OF BRANDON BYLO, CORNELIUS RODGERS, AND  ANONYMOUS',
#  'HONORING THE HEROIC ACTIONS OF FIVE NEW YORK FIRST RESPONDERS IN  VALATIE, NEW YORK',
#  'HONORING THE HEROIC ACTIONS OF MANHEIM TOWNSHIP POLICE OFFICERS KYLE  CARNER AND ANTHONY DICLEMENTE',
#  'HONORING THE HEROIC ACTIONS OF RICO BRIGGS',
#  'HONORING THE NATIONAL ACTIVE AND RETIRED FEDERAL EMPLOYEES WOODBRIDGE  CHAPTER 1270 ON THEIR 50TH ANNIVERSARY',
#  'HOUSE MUST ACT NOW TO END GUN VIOLENCE',
#  'HOUSING OUR MILITARY VETERANS EFFECTIVELY ACT OF 2023',
#  'I-27 NUMBERING ACT OF 2023',
#  'IMPACTT HUMAN TRAFFICKING ACT',
#  'IMPROVING ACCESS TO SMALL BUSINESS INFORMATION ACT',
#  'IN RECOGNITION OF CAPTAIN ZACH EVANS AND CAPTAIN JOSHUA SADDLER FOR  THEIR LIFESAVING ACTIONS',
#  'INFLATION REDUCTION ACT',
#  'INFORMING CONSUMERS ABOUT SMART DEVICES ACT',
#  'INSTITUTE FOR TELECOMMUNICATION SCIENCES CODIFICATION ACT',
#  'INTELLIGENCE AUTHORIZATION ACT FOR FISCAL YEAR 2024',
#  'INTRODUCTION OF AN ACT TO EXPAND THE MISSION OF THE NATIONAL PARK  SERVICE TO INCLUDE ACTIVE USE OF SYSTEM UNITS LOCATED IN URBAN AREAS',
#  'INTRODUCTION OF CLEAN WATER SRF PARITY ACT',
#  'INTRODUCTION OF THE AANAPISI OPPORTUNITY ACT',
#  'INTRODUCTION OF THE AFGHAN ADJUSTMENT ACT',
#  'INTRODUCTION OF THE ALBERT PIKE STATUE REMOVAL ACT',
#  'INTRODUCTION OF THE ANDREW JACKSON STATUE REMOVAL ACT',
#  'INTRODUCTION OF THE BAYARD RUSTIN STAMP ACT',
#  'INTRODUCTION OF THE BICYCLE COMMUTER ACT',
#  'INTRODUCTION OF THE BUSINESS UNINTERRUPTED MONETARY PROGRAM ACT',
#  'INTRODUCTION OF THE COMMISSION OF FINE ARTS DISTRICT OF COLUMBIA  RESIDENCY ACT',
#  'INTRODUCTION OF THE COMMISSION OF FINE ARTS DISTRICT OF COLUMBIA HOME  RULE ACT',
#  'INTRODUCTION OF THE DEFENSE ACCESS ROADS IMPROVEMENT ACT',
#  'INTRODUCTION OF THE DIANNE FEINSTEIN LAKE TAHOE RESTORATION ACT',
#  'INTRODUCTION OF THE DISTRICT OF COLUMBIA BOARD OF ZONING ADJUSTMENT  HOME RULE ACT',
#  'INTRODUCTION OF THE DISTRICT OF COLUMBIA CLEMENCY HOME RULE ACT',
#  'INTRODUCTION OF THE DISTRICT OF COLUMBIA CODE RETURNING CITIZENS  COORDINATION ACT',
#  'INTRODUCTION OF THE DISTRICT OF COLUMBIA COURTS AND PUBLIC DEFENDER  SERVICE EMPLOYMENT NON-DISCRIMINATION ACT',
#  'INTRODUCTION OF THE DISTRICT OF COLUMBIA COURTS HOME RULE ACT',
#  'INTRODUCTION OF THE DISTRICT OF COLUMBIA COURTS JUDICIAL VACANCY  REDUCTION ACT',
#  'INTRODUCTION OF THE DISTRICT OF COLUMBIA ELECTRONIC TRANSMITTAL OF  LEGISLATION ACT',
#  'INTRODUCTION OF THE DISTRICT OF COLUMBIA FEDERAL JUDICIAL OFFICIALS  RESIDENCY EQUALITY ACT',
#  'INTRODUCTION OF THE DISTRICT OF COLUMBIA GOVERNMENT TITLE EQUALITY ACT',
#  'INTRODUCTION OF THE DISTRICT OF COLUMBIA JUROR PAY PARITY ACT',
#  'INTRODUCTION OF THE DISTRICT OF COLUMBIA LEGISLATIVE HOME RULE ACT',
#  'INTRODUCTION OF THE DISTRICT OF COLUMBIA NATIONAL GUARD COMMANDING  GENERAL RESIDENCY ACT',
#  'INTRODUCTION OF THE DISTRICT OF COLUMBIA NATIONAL GUARD FEDERAL  EMPLOYEE LEAVE FAIRNESS ACT',
#  'INTRODUCTION OF THE DISTRICT OF COLUMBIA NATIONAL GUARD HOME RULE ACT',
#  'INTRODUCTION OF THE DISTRICT OF COLUMBIA NON-DISCRIMINATION HOME RULE  ACT OF 2023',
#  'INTRODUCTION OF THE DISTRICT OF COLUMBIA POLICE HOME RULE ACT',
#  'INTRODUCTION OF THE DISTRICT OF COLUMBIA PROSECUTOR HOME RULE ACT OF',
#  'INTRODUCTION OF THE DISTRICT OF COLUMBIA SPECIAL ELECTIONS HOME RULE  ACT',
#  'INTRODUCTION OF THE DISTRICT OF COLUMBIA TRANSPORTATION FUNDING  EQUALITY ACT',
#  'INTRODUCTION OF THE DISTRICT OF COLUMBIA ZONING COMMISSION HOME RULE  ACT',
#  'INTRODUCTION OF THE EMANCIPATION STATUE REMOVAL ACT',
#  'INTRODUCTION OF THE END OIL AND GAS TAX SUBSIDES ACT',
#  'INTRODUCTION OF THE EXPEDITED FEDERAL PERMITTING FOR CALIFORNIA ACT',
#  'INTRODUCTION OF THE FAIR COLA FOR SENIORS ACT OF 2023',
#  'INTRODUCTION OF THE FEDERAL GIFT SHOP TAX ACT',
#  'INTRODUCTION OF THE FEDERAL GOVERNMENT ADVERTISING EQUITY  ACCOUNTABILITY ACT',
#  'INTRODUCTION OF THE FEDERAL POLICE CAMERA AND ACCOUNTABILITY ACT OF',
#  'INTRODUCTION OF THE FEDERAL RETIREMENT THRIFT INVESTMENT BOARD  INSPECTOR GENERAL ACT OF 2023',
#  'INTRODUCTION OF THE FOOD AND FARM ACT',
#  'INTRODUCTION OF THE FOOD DESERTS ACT',
#  'INTRODUCTION OF THE FOSTERING FAMILY COHESION NATIONWIDE ACT',
#  'INTRODUCTION OF THE FRANCIS G. NEWLANDS MEMORIAL REMOVAL ACT',
#  'INTRODUCTION OF THE HAWAII INVASIVE SPECIES PROTECTION ACT',
#  'INTRODUCTION OF THE HEMP ACCESS AND CONSUMER SAFETY ACT',
#  'INTRODUCTION OF THE IDEAL ACT',
#  'INTRODUCTION OF THE IMPROVING REENTRY FOR DISTRICT OF COLUMBIA  RESIDENTS IN THE BUREAU OF PRISONS ACT OF 2023',
#  'INTRODUCTION OF THE INSULAR AREA MEDICAID PARITY ACT',
#  'INTRODUCTION OF THE JURY DUTY EXEMPTION FOR BREASTFEEDING ACT OF 2023',
#  'INTRODUCTION OF THE LAW ENFORCEMENT TRAINING FOR MENTAL HEALTH CRISIS  RESPONSE ACT OF 2023',
#  'INTRODUCTION OF THE MANUFACTURING PARTNERSHIP IMPROVEMENT ACT',
#  'INTRODUCTION OF THE MEDICAID ACCOUNTABILITY ACT OF 2023',
#  'INTRODUCTION OF THE NATIONAL CAPITAL PLANNING COMMISSION DISTRICT OF  COLUMBIA HOME RULE ACT',
#  'INTRODUCTION OF THE NO FENCING AT THE UNITED STATES SUPREME COURT ACT',
#  'INTRODUCTION OF THE NO TAX SUBSIDIES FOR STADIUMS ACT',
#  'INTRODUCTION OF THE NORTHERN MARIANA ISLANDS ENTREPRENEURSHIP ACT OF',
#  'INTRODUCTION OF THE NORTHERN MARIANA ISLANDS MEDICAID EQUIVALENCE ACT',
#  'INTRODUCTION OF THE NORTHERN MARIANA ISLANDS POPULATION STABILIZATION  ACT',
#  'INTRODUCTION OF THE NUCLEAR WEAPONS ABOLITION AND CONVERSION ACT OF',
#  'INTRODUCTION OF THE OCEAN SHIPPING COMPETITION ENFORCEMENT ACT',
#  'INTRODUCTION OF THE PAY EQUITY FOR ALL ACT OF 2023',
#  'INTRODUCTION OF THE POSTAL FACILITIES SECURITY CAMERA ACT',
#  'INTRODUCTION OF THE PROMOTING ACCESS TO DIABETIC SHOES ACT',
#  'INTRODUCTION OF THE PROMOTING REDUCTION OF EMISSIONS THROUGH  LANDSCAPING EQUIPMENT ACT',
#  'INTRODUCTION OF THE PROTECTING INDEPENDENT CONTRACTORS FROM  DISCRIMINATION ACT',
#  'INTRODUCTION OF THE PUBLIC INSPECTORS FOR SAFE INFRASTRUCTURE ACT',
#  'INTRODUCTION OF THE REBUILDING THE UNITED STATES-FLAG INTERNATIONAL  FLEET ACT',
#  'INTRODUCTION OF THE RED HILL HEALTH IMPACT ACT',
#  'INTRODUCTION OF THE REDUCING HELICOPTER NOISE IN THE DISTRICT OF  COLUMBIA ACT',
#  'INTRODUCTION OF THE RESTAURANT REVITALIZATION TAX CREDIT ACT',
#  'INTRODUCTION OF THE RESTROOM ACCESS ACT OF 2023',
#  'INTRODUCTION OF THE RIGHT TO TRY CLARIFICATION ACT',
#  'INTRODUCTION OF THE SALARY TRANSPARENCY ACT',
#  'INTRODUCTION OF THE SARAH DEBBINK LANGENKAMP ACTIVE TRANSPORTATION  SAFETY ACT',
#  'INTRODUCTION OF THE SECURE AND FAIR ENFORCEMENT BANKING ACT',
#  'INTRODUCTION OF THE SECURITIES AND EXCHANGE COMMISSION REAL ESTATE  LEASING AUTHORITY REVOCATION ACT',
#  'INTRODUCTION OF THE SMALL BUSINESS TAX EQUITY ACT',
#  'INTRODUCTION OF THE SMARTER APPROACHES TO NUCLEAR EXPENDITURES (SANE)  ACT',
#  'INTRODUCTION OF THE SPECIAL IMMIGRANT VISAS FOR AFGHAN FULBRIGHT  SCHOLARS ACT',
#  'INTRODUCTION OF THE SUSTAINABLE BUDGET ACT',
#  'INTRODUCTION OF THE TRAIN NOISE AND VIBRATIONS REDUCTION ACT',
#  'INTRODUCTION OF THE TRAVEL FOR CARE ACT',
#  'INTRODUCTION OF THE UNITED STATES COLORED TROOPS CONGRESSIONAL GOLD  MEDAL ACT',
#  'INTRODUCTION OF THE UNITED STATES COMMISSION ON AN OPEN SOCIETY WITH  SECURITY ACT OF 2023',
#  'INTRODUCTION OF THE VETERANS EQUAL ACCESS ACT',
#  'INTRODUCTION OF THE VOTE AT HOME ACT',
#  'INTRODUCTION OF THE WASHINGTON, D.C. ADMISSION ACT',
#  'INTRODUCTION OF THE WORDS MATTER FOR THE DISTRICT OF COLUMBIA COURTS  ACT',
#  "INTRODUCTION OF THE WY'EAST TRIBAL RESOURCES RESTORATION ACT",
#  'INTRODUCTION OF THE YOUNG AMERICANS FINANCIAL LITERACY ACT',
#  'INVESTING IN MAIN STREET ACT OF 2023',
#  'ISAKSON-ROE EDUCATION OVERSIGHT EXPANSION ACT',
#  'ISRAEL SECURITY SUPPLEMENTAL APPROPRIATIONS ACT, 2024',
#  'JUDICIARY ACT OF 2023',
#  'JUSTICE FOR JANA ELEMENTARY ACT OF 2023',
#  'KOREAN AMERICAN VIETNAM ALLIES LONG OVERDUE FOR RELIEF ACT',
#  'LAUNCH COMMUNICATIONS ACT',
#  'LAW ENFORCEMENT DE-ESCALATION TRAINING ACT',
#  'LEGISLATIVE BRANCH APPROPRIATIONS ACT, 2024',
#  'LIMIT, SAVE, GROW ACT OF 2023',
#  'LOWER COSTS, MORE TRANSPARENCY ACT',
#  'LOWER ENERGY COSTS ACT',
#  'MAHSA AMINI HUMAN RIGHTS AND SECURITY ACCOUNTABILITY ACT',
#  'MICROLOAN TRANSPARENCY AND ACCOUNTABILITY ACT OF 2023',
#  'MIDDLE CLASS BORROWER PROTECTION ACT OF 2023',
#  'MIDDLE MARKET IPO COST ACT',
#  'MILITARY CONSTRUCTION, VETERANS AFFAIRS, AND RELATED AGENCIES  APPROPRIATIONS ACT, 2024',
#  'MILITARY PERSONNEL CONFIRMATION RESTORATION ACT OF 2023',
#  'MODERNIZING THE ACQUISITION OF CYBERSECURITY EXPERTS ACT OF 2023',
#  'MOTION TO INSTRUCT CONFEREES ON H.R. 2670, NATIONAL DEFENSE  AUTHORIZATION ACT FOR FISCAL YEAR 2024',
#  'NATIONAL DEFENSE AUTHORIZATION ACT FOR FISCAL YEAR 2024',
#  'NATIONAL DEFENSE AUTHORIZATION ACT FOR FISCAL YEAR 2024--CONFERENCE',
#  'NATIONAL DEFENSE AUTHORIZATION ACT FOR FISCAL YEAR 2024--CONFERENCE  REPORT--MOTION TO PROCEED',
#  'NATIONAL GUARD AND RESERVISTS DEBT RELIEF EXTENSION ACT OF 2023',
#  'NATIONAL SENIOR INVESTOR INITIATIVE ACT OF 2023',
#  'NATIVE AMERICAN CHILD PROTECTION ACT',
#  'NDO FAIRNESS ACT',
#  'NO FUNDS FOR IRANIAN TERRORISM ACT',
#  'NO STOLEN TRADEMARKS HONORED IN AMERICA ACT OF 2023',
#  'NOTAM IMPROVEMENT ACT OF 2023',
#  'NTIA POLICY AND CYBERSECURITY COORDINATION ACT',
#  'ONE SEAT RIDE ACT',
#  "OPPOSING H.R. 1615, THE ``GAS STOVE PROTECTION AND FREEDOM ACT'' AND  H.R. 1640, THE ``SAVE OUR STOVES ACT''",
#  "OPPOSING H.R. 1615, THE ``GAS STOVE PROTECTION OF FREEDOM ACT'' AND  H.R. 1640, THE ``SAVE OUR GAS STOVES ACT''",
#  'OPPOSING THE CHOICE IN AUTOMOBILE RETAIL SALES ACT OF 2023',
#  'OPPOSING THE DEFAULT ON AMERICA ACT',
#  'OPPOSITION TO H.J. RES. 26 DISAPPROVING THE ACTION OF THE DISTRICT OF  COLUMBIA COUNCIL IN APPROVING THE REVISED CRIMINAL CODE ACT OF 2022',
#  'OPPOSITION TO LEADED AVIATION FUEL PROVISIONS IN H.R. 3935, THE  SECURING GROWTH AND ROBUST LEADERSHIP IN AMERICAN AVIATION ACT',
#  'ORBITAL SUSTAINABILITY ACT OF 2023',
#  'PALA BAND OF MISSION INDIANS LAND TRANSFER ACT OF 2023',
#  'PANDEMIC IS OVER ACT',
#  'PAPERWORK BURDEN REDUCTION ACT',
#  'PARENTS BILL OF RIGHTS ACT',
#  'PAY OUR TROOPS ACT',
#  "PAY WORKERS WHAT THEY'VE EARNED ACT",
#  "PAYING TRIBUTE TO OUR NATION'S PRISONERS OF WAR AND THOSE WHO ARE  MISSING IN ACTION",
#  'PEACE AND TOLERANCE IN PALESTINIAN EDUCATION ACT',
#  "PERIODIC REVIEWS AND UPDATED REPORTS OF THE DEPARTMENT OF STATE'S  TAIWAN GUIDELINES UNDER THE TAIWAN ASSURANCE ACT OF 2020",
#  'POST-DISASTER ASSISTANCE ONLINE ACCOUNTABILITY ACT',
#  'PRC IS NOT A DEVELOPING COUNTRY ACT',
#  'PRECISION AGRICULTURE SATELLITE CONNECTIVITY ACT',
#  'PREEMIE REAUTHORIZATION ACT OF 2023',
#  'PRESERVING CHOICE IN VEHICLE PURCHASES ACT',
#  'PREVENTING THE FINANCING OF ILLEGAL SYNTHETIC DRUGS ACT',
#  'PROHIBITING RUSSIAN URANIUM IMPORTS ACT',
#  'PROMOTING OPPORTUNITIES FOR NON-TRADITIONAL CAPITAL FORMATION ACT',
#  'PROMOTING RESILIENT BUILDINGS ACT OF 2023',
#  'PROTECT OUR LAW ENFORCEMENT WITH IMMIGRATION CONTROL AND ENFORCEMENT  ACT OF 2023',
#  "PROTECTING AMERICA'S STRATEGIC PETROLEUM RESERVE FROM CHINA ACT",
#  'PROTECTING CHILDREN WITH FOOD ALLERGIES ACT',
#  'PROTECTING HUNTING HERITAGE AND EDUCATION ACT',
#  'PROTECTING OUR COMMUNITIES FROM FAILURE TO SECURE THE BORDER ACT OF',
#  'PROTECTING SPEECH FROM GOVERNMENT INTERFERENCE ACT',
#  'PROTECTING TAXPAYERS AND VICTIMS OF UNEMPLOYMENT FRAUD ACT',
#  'PROTECTION OF WOMEN AND GIRLS IN SPORTS ACT OF 2023',
#  'PROVIDING ACCOUNTABILITY THROUGH TRANSPARENCY ACT OF 2023',
#  'PROVIDING APPROPRIATE RECOGNITION AND TREATMENT NEEDED TO ENHANCE  RELATIONS WITH ASEAN ACT',
#  "PROVIDING FOR CONGRESSIONAL DISAPPROVAL OF THE RULE SUBMITTED BY THE  BUREAU OF CONSUMER FINANCIAL PROTECTION RELATING TO ``SMALL BUSINESS  LENDING UNDER THE EQUAL CREDIT OPPORTUNITY ACT (REGULATION B)''",
#  "PROVIDING FOR CONGRESSIONAL DISAPPROVAL UNDER CHAPTER 8 OF TITLE 5,  UNITED STATES CODE, OF THE RULE SUBMITTED BY THE BUREAU OF CONSUMER  FINANCIAL PROTECTION RELATING TO ``SMALL BUSINESS LENDING UNDER THE  EQUAL CREDIT OPPORTUNITY ACT (REGULATION B)''--VETO",
#  'PROVIDING FOR CONSIDERATION OF H.R. 1, LOWER ENERGY COSTS ACT',
#  'PROVIDING FOR CONSIDERATION OF H.R. 1147, WHOLE MILK FOR HEALTHY KIDS  ACT OF 2023; PROVIDING FOR CONSIDERATION OF H.R. 357, ENSURING  ACCOUNTABILITY IN AGENCY RULEMAKING ACT; AND FOR OTHER PURPOSES',
#  'PROVIDING FOR CONSIDERATION OF H.R. 140, PROTECTING SPEECH FROM  GOVERNMENT INTERFERENCE ACT; PROVIDING FOR CONSIDERATION OF H.J. RES.',
#  'PROVIDING FOR CONSIDERATION OF H.R. 2, SECURE THE BORDER ACT OF 2023;  PROVIDING FOR CONSIDERATION OF H.R. 1163, PROTECTING TAXPAYERS AND  VICTIMS OF UNEMPLOYMENT FRAUD ACT',
#  'PROVIDING FOR CONSIDERATION OF H.R. 2494, PROTECT OUR LAW ENFORCEMENT  WITH IMMIGRATION CONTROL AND ENFORCEMENT ACT OF 2023; PROVIDING FOR  CONSIDERATION OF H.R. 3091, FEDERAL LAW ENFORCEMENT OFFICER SERVICE  WEAPON PURCHASE ACT; AND PROVIDING FOR CONSIDERATION OF H. CON. RES.',
#  'PROVIDING FOR CONSIDERATION OF H.R. 2670, NATIONAL DEFENSE  AUTHORIZATION ACT FOR FISCAL YEAR 2024',
#  'PROVIDING FOR CONSIDERATION OF H.R. 2811, LIMIT, SAVE, GROW ACT OF',
#  'PROVIDING FOR CONSIDERATION OF H.R. 3564, MIDDLE CLASS BORROWER  PROTECTION ACT OF 2023; PROVIDING FOR CONSIDERATION OF H.R. 3799,  CUSTOM HEALTH OPTION AND INDIVIDUAL CARE EXPENSE ARRANGEMENT ACT; AND  PROVIDING FOR CONSIDERATION OF H. RES. 461, CONDEMNING THE USE OF  ELEMENTARY AND SECONDARY SCHOOL FACILITIES TO PROVIDE SHELTER FOR  ALIENS WHO ARE NOT ADMITTED TO THE UNITED STATES',
#  'PROVIDING FOR CONSIDERATION OF H.R. 4365, DEPARTMENT OF DEFENSE  APPROPRIATIONS ACT, 2024; PROVIDING FOR CONSIDERATION OF H.R. 1130,  UNLOCKING OUR DOMESTIC LNG POTENTIAL ACT OF 2023; AND PROVIDING FOR',
#  'PROVIDING FOR CONSIDERATION OF H.R. 4365, DEPARTMENT OF DEFENSE  APPROPRIATIONS ACT, 2024; PROVIDING FOR CONSIDERATION OF H.R. 4367,',
#  'PROVIDING FOR CONSIDERATION OF H.R. 4366, MILITARY CONSTRUCTION,  VETERANS AFFAIRS, AND RELATED AGENCIES APPROPRIATIONS ACT, 2024;',
#  'PROVIDING FOR CONSIDERATION OF H.R. 4664, FINANCIAL SERVICES AND  GENERAL GOVERNMENT APPROPRIATIONS ACT, 2024',
#  'PROVIDING FOR CONSIDERATION OF H.R. 4821, DEPARTMENT OF THE INTERIOR,  ENVIRONMENT, AND RELATED AGENCIES APPROPRIATIONS ACT, 2024; PROVIDING  FOR CONSIDERATION OF H.R. 4820, TRANSPORTATION, HOUSING AND URBAN  DEVELOPMENT, AND RELATED AGENCIES APPROPRIATIONS ACT, 2024; AND',
#  'PROVIDING FOR CONSIDERATION OF H.R. 5, PARENTS BILL OF RIGHTS ACT',
#  "PROVIDING FOR CONSIDERATION OF H.R. 5283, PROTECTING OUR COMMUNITIES  FROM FAILURE TO SECURE THE BORDER ACT OF 2023; PROVIDING FOR  CONSIDERATION OF H.R. 5961, NO FUNDS FOR IRANIAN TERRORISM ACT; AND  PROVIDING FOR CONSIDERATION OF S.J. RES. 32, PROVIDING FOR  CONGRESSIONAL DISAPPROVAL OF THE RULE SUBMITTED BY THE BUREAU OF  CONSUMER FINANCIAL PROTECTION RELATING TO ``SMALL BUSINESS LENDING  UNDER THE EQUAL CREDIT OPPORTUNITY ACT (REGULATION B)''",
#  'PROVIDING FOR CONSIDERATION OF H.R. 5692, UKRAINE SECURITY ASSISTANCE  AND OVERSIGHT SUPPLEMENTAL APPROPRIATIONS ACT, 2024; PROVIDING FOR  FURTHER CONSIDERATION OF H.R. 4365, DEPARTMENT OF DEFENSE  APPROPRIATIONS ACT, 2024; AND PROVIDING FOR FURTHER CONSIDERATION OF  H.R. 4367, DEPARTMENT OF HOMELAND SECURITY APPROPRIATIONS ACT, 2024',
#  'PROVIDING FOR CONSIDERATION OF H.R. 5893, COMMERCE, JUSTICE, SCIENCE,  AND RELATED AGENCIES APPROPRIATIONS ACT, 2024; AND PROVIDING FOR  CONSIDERATION OF H.R. 5961, NO FUNDS FOR IRANIAN TERRORISM ACT',
#  'PROVIDING FOR FURTHER CONSIDERATION OF H.R. 2670, NATIONAL DEFENSE  AUTHORIZATION ACT FOR FISCAL YEAR 2024',
#  'PUERTO RICO ACT 22',
#  'RECOGNIZING STOP PENTAGON PRICE GOUGING ACT',
#  'RECOGNIZING THE 20TH ANNIVERSARY OF THE PRISON RAPE ELIMINATION ACT',
#  'RECOGNIZING THE 30TH ANNIVERSARY OF THE FAMILY MEDICAL LEAVE ACT',
#  'RECOGNIZING THE 75TH ANNIVERSARY OF THE WOMENS ARMED SERVICES ACT AND  TO HONOR AND REMEMBER THE SACRIFICE AND SERVICE OF WOMEN VETERANS',
#  'RECOGNIZING THE BLUE PACIFIC ACT',
#  'RECOGNIZING THE COURAGEOUS ACTIONS OF FLUVANNA COUNTY LIFEGUARDS',
#  'RECOGNIZING THE FARMERS MARKET AND FOOD BANK LOCAL REVITALIZATION ACT',
#  'RECOGNIZING THE HEROIC ACTIONS AND EXCEPTIONAL BRAVERY OF OWEN BURNS',
#  'RECOGNIZING THE NEED FOR FEDERAL ACTION TO PREVENT GUN VIOLENCE',
#  'REDUCE EXACERBATED INFLATION NEGATIVELY IMPACTING THE NATION ACT',
#  'REFORM THE ENDANGERED SPECIES ACT',
#  'REGULATIONS FROM THE EXECUTIVE IN NEED OF SCRUTINY ACT OF 2023',
#  'REINS ACT',
#  'REINTRODUCTION OF PEACE CORPS REAUTHORIZATION ACT OF 2023',
#  'REINTRODUCTION OF THE AMERICAN FOOD FOR AMERICAN SCHOOLS ACT OF 2023',
#  'REINTRODUCTION OF THE AMERICAN PORT ACCESS PRIVILEGES ACT OF 2023',
#  'REINTRODUCTION OF THE BASE ACCESS PRIVILEGES IMPROVEMENT ACT',
#  'REINTRODUCTION OF THE BERRYESSA SNOW MOUNTAIN NATIONAL MONUMENT  EXPANSION ACT',
#  'REINTRODUCTION OF THE BRIDGE CORROSION PREVENTION AND REPAIR ACT OF',
#  'REINTRODUCTION OF THE CABIN AIR SAFETY ACT',
#  'REINTRODUCTION OF THE EMERGING BUSINESS ENCOURAGEMENT ACT OF 2023',
#  'REINTRODUCTION OF THE ENERGIZING AMERICAN SHIPBUILDING ACT OF 2023',
#  'REINTRODUCTION OF THE FEDERAL SHIP FINANCING IMPROVEMENT ACT',
#  'REINTRODUCTION OF THE JUSTICE FOR SHIREEN ACT',
#  'REINTRODUCTION OF THE MILITARY SUPPORT FOR FIGHTING WILDFIRES ACT',
#  'REINTRODUCTION OF THE RESPECT FOR GRIEVING MILITARY FAMILIES ACT',
#  'REINTRODUCTION OF THE STUDENTS HELPING YOUNG STUDENTS ACT',
#  'REINTRODUCTION OF THE TRANSITION-TO-SUCCESS MENTORING ACT',
#  'REMOVING EXTRANEOUS LOOPHOLES INSURING EVERY VETERAN EMERGENCY ACT',
#  'REMOVING EXTRANEOUS LOOPHOLES INSURING EVERY VETERAN EMERGENCY ACT--',
#  'RENEWABLE FUEL FOR OCEAN-GOING VESSELS ACT',
#  'REPUBLICAN FAILURE TO ACT ON DEBT CEILING',
#  'RESCINDING THE UNILATERAL STUDENT LOAN FORGIVENESS EXECUTIVE ACTION',
#  'REVISING EXISTING PROCEDURES ON REPORTING VIA TECHNOLOGY ACT',
#  'RIO SAN JOSE AND RIO JEMEZ WATER SETTLEMENTS ACT OF 2023',
#  'SATELLITE AND TELECOMMUNICATIONS STREAMLINING ACT',
#  'SAVE OUR GAS STOVES ACT',
#  'SAVING NEMO ACT',
#  'SCHOOLS NOT SHELTERS ACT',
#  'SECURE THE BORDER ACT 2023',
#  'SECURE THE BORDER ACT OF 2023',
#  'SECURING GROWTH AND ROBUST LEADERSHIP IN AMERICAN AVIATION ACT',
#  'SECURING SEMICONDUCTOR SUPPLY CHAINS ACT OF 2023',
#  'SECURING THE U.S. ORGAN PROCUREMENT AND TRANSPLANTATION NETWORK ACT',
#  'SECURITIES AND EXCHANGE COMMISSION REAL ESTATE LEASING AUTHORITY  REVOCATION ACT',
#  'SENATE MUST ACT ON IMMIGRATION CRISIS',
#  'SETTLEMENT AGREEMENT INFORMATION DATABASE ACT OF 2023',
#  'SILETZ RESERVATION ACT AMENDMENT',
#  'SMALL BUSINESS ADVOCACY IMPROVEMENTS ACT OF 2023',
#  'SMALL BUSINESS CONTRACTING TRANSPARENCY ACT OF 2023',
#  'SMALL ENTITY UPDATE ACT',
#  'SOO LOCKS SECURITY AND ECONOMIC REPORTING ACT OF 2023',
#  'SPECIAL ENVOY FOR THE ABRAHAM ACCORDS ACT',
#  'STOP CHINESE FENTANYL ACT OF 2023',
#  'STOP FORCED ORGAN HARVESTING ACT OF 2023',
#  'STOP HARBORING IRANIAN PETROLEUM ACT',
#  "STOPPING HOME OFFICE WORK'S UNPRODUCTIVE PROBLEMS ACT OF 2023",
#  'STRATEGIC PRODUCTION RESPONSE ACT',
#  'STRENGTHENING COASTAL COMMUNITIES ACT OF 2023',
#  'SUCCESSFUL ENTREPRENEURSHIP FOR RESERVISTS AND VETERANS ACT',
#  'SUPPORT FOR PATIENTS AND COMMUNITIES REAUTHORIZATION ACT',
#  'SUPPORTING THE OMNIBUS APPROPRIATIONS AND CONSOLIDATED APPROPRIATIONS  ACT, 2023',
#  'SUPPORTING THE RIGHT TO CONTRACEPTION ACT',
#  'SUPREME COURT DECISION ON AFFIRMATIVE ACTION WILL HAVE DEVASTATING  EFFECTS',
#  'SUPREME COURT ETHICS, RECUSAL, AND TRANSPARENCY ACT',
#  'SUSTAINABLE BUDGET ACT',
#  'TAIWAN INTERNATIONAL SOLIDARITY ACT',
#  'TAKE ACTION ON GUN VIOLENCE',
#  'TECHNICAL CORRECTION TO THE SHOSHONE-PAIUTE TRIBES OF THE DUCK VALLEY  RESERVATION WATER RIGHTS SETTLEMENT ACT OF 2023',
#  'TESTING, RAPID ANALYSIS, AND NARCOTIC QUALITY RESEARCH ACT',
#  'THERE IS STILL TIME TO ACT',
#  'TIME TO ACT',
#  'TRANSPORTATION, HOUSING AND URBAN DEVELOPMENT, AND RELATED AGENCIES  APPROPRIATIONS ACT, 2024',
#  'TREATING TRIBES AND COUNTIES AS GOOD NEIGHBORS ACT',
#  'U.S. CUSTOMS AND BORDER PROTECTION OFFICER RETIREMENT TECHNICAL  CORRECTIONS ACT',
#  'U.S. SUPPLY CHAIN SECURITY REVIEW ACT OF 2023',
#  'U.S.-RUSSIAN FEDERATION SEAFOOD RECIPROCITY ACT',
#  'UDALL FOUNDATION REAUTHORIZATION ACT OF 2023',
#  'UKRAINE SECURITY ASSISTANCE AND OVERSIGHT SUPPLEMENTAL APPROPRIATIONS  ACT, 2024',
#  'UNDERSEA CABLE CONTROL ACT',
#  'UNDERSTANDING CYBERSECURITY OF MOBILE NETWORKS ACT',
#  'UNITED STATES-TAIWAN INITIATIVE ON 21ST-CENTURY TRADE FIRST AGREEMENT  IMPLEMENTATION ACT',
#  'UNMANNED AERIAL SECURITY ACT',
#  'UPHOLDING SOVEREIGNTY OF AIRSPACE ACT',
#  'URBAN INDIAN HEALTH CONFER ACT',
#  'VET-TEC AUTHORIZATION ACT OF 2023',
#  'VETERAN ENTREPRENEURSHIP TRAINING ACT OF 2023',
#  'VETERANS BENEFITS IMPROVEMENT ACT OF 2023',
#  "VETERANS' COMPENSATION COST-OF-LIVING ADJUSTMENT ACT OF 2023",
#  'VOTE AGAINST H.R. 3099, THE SPECIAL ENVOY FOR ABRAHAM ACCORDS ACT',
#  'WE HAVE MUCH TO GAIN FROM OUR RELATIONSHIP WITH BRAZIL, BUT WE STILL  NEED TO ACT',
#  'WHAT PEOPLE ARE SAYING: THE PROTECTING THE RIGHT TO ORGANIZE ACT',
#  'WHOLE MILK FOR HEALTHY KIDS ACT OF 2023',
#  "WOMEN'S HEALTH PROTECTION ACT",
#  "WOMEN'S SUFFRAGE NATIONAL MONUMENT LOCATION ACT",
#  'WOUNDED KNEE MASSACRE MEMORIAL AND SACRED SITE ACT',
#  'WOUNDED WARRIOR ACCESS ACT']
